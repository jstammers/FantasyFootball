# %%
import shutil
import time

from bayesball.schema import MatchSummarySchema

"""A module to ingest data from the FBRef website"""
import dataclasses
import logging as log
import os
import polars as pl
from pathlib import Path
from rich.progress import track
from concurrent.futures import ProcessPoolExecutor, as_completed

from bayesball.worldfootballr import call_wf_function, fb_parse_match_data
from bayesball.utils import (
    get_current_season,
    maybe_download_file,
    setup_logging,
    r_to_python,
)
from bayesball.config import (
    ADVANCED_MATCH_STATS,
    COUNTRIES,
    TIERS,
    MIN_SEASON_END_YEAR,
    LEAGUE_STATS,
)
from bayesball.models import AdvancedMatchStats, MatchStats

STAGE_DIR = "data/ingest/stage"

BASE_DIR = "data/ingest/fbref"

SOURCE_SUFFIX = "fbref"
GENDER = "M"

# %%
df = pl.read_csv("./data/ingest/fbref/advanced_match_stats/player/defense/ENG_M_1st_wf.csv")

# %%
import pandera as pa

MatchSummarySchema = pa.DataFrameSchema(
    {
        "MatchURL": pa.Column(str),
        "League": pa.Column(str),
        "Match_Date": pa.Column(pa.Date),
        "Matchweek": pa.Column(str),
        "Home_Team": pa.Column(str),
        "Home_Formation": pa.Column(str, nullable=True),
        "Home_Score": pa.Column(int, default=0),
        "Home_xG": pa.Column(float, nullable=True),
        "Home_Goals": pa.Column(str, nullable=True),
        "Home_Yellow_Cards": pa.Column(int),
        "Home_Red_Cards": pa.Column(int),
        "Away_Team": pa.Column(str),
        "Away_Formation": pa.Column(str, nullable=True),
        "Away_Score": pa.Column(int, nullable=True, default=0),
        "Away_xG": pa.Column(float, nullable=True),
        "Away_Goals": pa.Column(str, nullable=True),
        "Away_Yellow_Cards": pa.Column(int),
        "Away_Red_Cards": pa.Column(int),
        "Game_URL": pa.Column(str),
        "Team": pa.Column(str),
        "Home_Away": pa.Column(str),
        "Event_Time": pa.Column(str),
        "Is_Pens": pa.Column(str),
        "Event_Half": pa.Column(str),
        "Event_Type": pa.Column(str),
        "Event_Players": pa.Column(str),
        "Score_Progression": pa.Column(str, nullable=True),
        "Penalty_Number": pa.Column(str, nullable=True),
        "Competition_Name": pa.Column(str),
        "Gender": pa.Column(str),
        "Country": pa.Column(str),
        "Tier": pa.Column(str),
        "Season_End_Year": pa.Column(int),
    },
    coerce=True,
    strict=True,
)

# %%
    competitions = pl.read_csv(Path(BASE_DIR) / "competitions.csv").rename(
        {
            "country": "Country",
            "tier": "Tier",
            "season_end_year": "Season_End_Year",
            "gender": "Gender",
            "competition_name": "Competition_Name",
        }
    )

# %%
match_summary_files = Path(BASE_DIR) / "match_summary"

for f in match_summary_files.glob("*.csv"):
    df = pl.read_csv(f)
    # if "Competition_Name" not in df.columns:
    #     df = df.join(competitions.select("Country", "Gender", "Tier", "Competition_Name"), on=["Country", "Gender", "Tier"], how="left")

    df_renamed = df.select(MatchSummarySchema.columns.keys())
    df_val = MatchSummarySchema.validate(df_renamed.to_pandas())
    if df_renamed.schema != df.schema:
        df_renamed.write_csv(f)
# Out:
# /home/jimmy/Code/FantasyFootball/.venv/lib/python3.12/site-packages/pandera/backends/pandas/container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# /home/jimmy/Code/FantasyFootball/.venv/lib/python3.12/site-packages/pandera/backends/pandas/container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# /home/jimmy/Code/FantasyFootball/.venv/lib/python3.12/site-packages/pandera/backends/pandas/container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# /home/jimmy/Code/FantasyFootball/.venv/lib/python3.12/site-packages/pandera/backends/pandas/container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(

# %%
gender = "M"
match_summaries = pl.read_csv(Path(BASE_DIR) / "match_summary" / "*.csv")
match_shooting = pl.concat(
    [
        pl.read_csv(x)
        .select("Country", "Gender", "Tier", "Season_End_Year", "MatchURL")
        .unique()
        for x in (Path(BASE_DIR) / "match_shooting").glob("*.csv")
    ],
    how="diagonal_relaxed",
)
team_summary_stats = pl.concat(
    [
        pl.read_csv(x).select("MatchURL").unique()
        for x in (Path(BASE_DIR) / "advanced_match_stats" / "team" / "summary").glob(
            "*.csv"
        )
    ],
    how="diagonal_relaxed",
)
team_advanced_stats = pl.concat(
    [
        pl.read_csv(x).select("MatchURL").unique()
        for x in (Path(BASE_DIR) / "advanced_match_stats" / "team" / "possession").glob(
            "*.csv"
        )
    ],
    how="diagonal_relaxed",
)
tier_df = pl.DataFrame(LEAGUE_STATS)
match_results = (
    pl.read_csv(Path(BASE_DIR) / "match_results" / "*.csv")
    .join(tier_df, on=["Country", "Tier"])
    .filter(
        pl.col("Season_End_Year") >= MIN_SEASON_END_YEAR, pl.col("Gender") == gender
    )
)
match_shooting.filter(pl.col("Season_End_Year").is_null())
match_results_filtered = match_results.filter(
    ~pl.col("MatchURL").str.contains("History"),
    ~pl.col("Notes").fill_null("").str.contains("Cancelled"),
    ~pl.col("MatchURL").str.contains("RelegationPromotion-Play-offs"),
)
in_match_summary = (
    match_summaries.select("MatchURL").unique().with_columns(InMatchSummary=True)
)
in_team_match_summary = (
    team_summary_stats.select("MatchURL").unique().with_columns(InTeamSummary=True)
)
in_team_advanced_stats = (
    team_advanced_stats.select("MatchURL").unique().with_columns(InTeamAdvanced=True)
)
match_results_filtered = (
    match_results_filtered.join(in_match_summary, on="MatchURL", how="left")
    .join(in_team_match_summary, on="MatchURL", how="left")
    .join(in_team_advanced_stats, on="MatchURL", how="left")
    .fill_null(False)
)
missing_cond = (
    ~pl.col("InMatchSummary")
    | ~pl.col("InTeamSummary")
    | (
        ~pl.col("InTeamAdvanced")
        & (pl.col("Season_End_Year") >= pl.col("Min_Advanced_Season"))
    ).fill_null(False)
)
missing_matches = match_results_filtered.filter(missing_cond)
missing_matches = missing_matches.with_columns(
    filename=pl.lit(f"{STAGE_DIR}/html/")
    + pl.col("Country")
    + pl.lit("/")
    + pl.col("MatchURL").str.split("/").list.last()
    + pl.lit(".html"),
    match_id=pl.col("MatchURL").str.split("/").list[-2]
)

# %%
test = pl.read_csv("/home/jimmy/Code/FantasyFootball/data/ingest/fbref/match_summary/ENG_M_5th_match_summary_fbref*.csv")
# Out:
# ---------------------------------------------------------------------------
# ComputeError                              Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 test = pl.read_csv("/home/jimmy/Code/FantasyFootball/data/ingest/fbref/match_summary/ENG_M_5th_match_summary_fbref*.csv")
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/polars/_utils/deprecation.py:92, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      87 @wraps(function)
#      88 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#      89     _rename_keyword_argument(
#      90         old_name, new_name, kwargs, function.__qualname__, version
#      91     )
# ---> 92     return function(*args, **kwargs)
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/polars/_utils/deprecation.py:92, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      87 @wraps(function)
#      88 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#      89     _rename_keyword_argument(
#      90         old_name, new_name, kwargs, function.__qualname__, version
#      91     )
# ---> 92     return function(*args, **kwargs)
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/polars/_utils/deprecation.py:92, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      87 @wraps(function)
#      88 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#      89     _rename_keyword_argument(
#      90         old_name, new_name, kwargs, function.__qualname__, version
#      91     )
# ---> 92     return function(*args, **kwargs)
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/polars/io/csv/functions.py:527, in read_csv(source, has_header, columns, new_columns, separator, comment_prefix, quote_char, skip_rows, schema, schema_overrides, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, use_pyarrow, storage_options, skip_rows_after_header, row_index_name, row_index_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines, decimal_comma, glob)
#     519 else:
#     520     with prepare_file_arg(
#     521         source,
#     522         encoding=encoding,
#    (...)
#     525         storage_options=storage_options,
#     526     ) as data:
# --> 527         df = _read_csv_impl(
#     528             data,
#     529             has_header=has_header,
#     530             columns=columns if columns else projection,
#     531             separator=separator,
#     532             comment_prefix=comment_prefix,
#     533             quote_char=quote_char,
#     534             skip_rows=skip_rows,
#     535             schema_overrides=schema_overrides,
#     536             schema=schema,
#     537             null_values=null_values,
#     538             missing_utf8_is_empty_string=missing_utf8_is_empty_string,
#     539             ignore_errors=ignore_errors,
#     540             try_parse_dates=try_parse_dates,
#     541             n_threads=n_threads,
#     542             infer_schema_length=infer_schema_length,
#     543             batch_size=batch_size,
#     544             n_rows=n_rows,
#     545             encoding=encoding if encoding == "utf8-lossy" else "utf8",
#     546             low_memory=low_memory,
#     547             rechunk=rechunk,
#     548             skip_rows_after_header=skip_rows_after_header,
#     549             row_index_name=row_index_name,
#     550             row_index_offset=row_index_offset,
#     551             eol_char=eol_char,
#     552             raise_if_empty=raise_if_empty,
#     553             truncate_ragged_lines=truncate_ragged_lines,
#     554             decimal_comma=decimal_comma,
#     555             glob=glob,
#     556         )
#     558 if new_columns:
#     559     return _update_columns(df, new_columns)
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/polars/io/csv/functions.py:660, in _read_csv_impl(source, has_header, columns, separator, comment_prefix, quote_char, skip_rows, schema, schema_overrides, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, skip_rows_after_header, row_index_name, row_index_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines, decimal_comma, glob)
#     634 scan = scan_csv(
#     635     source,
#     636     has_header=has_header,
#    (...)
#     657     glob=glob,
#     658 )
#     659 if columns is None:
# --> 660     return scan.collect()
#     661 elif is_str_sequence(columns, allow_str=False):
#     662     return scan.select(columns).collect()
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/polars/lazyframe/frame.py:2029, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, streaming, engine, background, _eager, **_kwargs)
#    2027 # Only for testing purposes
#    2028 callback = _kwargs.get("post_opt_callback", callback)
# -> 2029 return wrap_df(ldf.collect(callback))
#
# ComputeError: schema lengths differ

# %%
test.group_by("Season_End_Year").len()
# Out:
# shape: (8, 2)
# ┌─────────────────┬──────┐
# │ Season_End_Year ┆ len  │
# │ ---             ┆ ---  │
# │ i64             ┆ u32  │
# ╞═════════════════╪══════╡
# │ 2023            ┆ 6475 │
# │ 2020            ┆ 4992 │
# │ 2024            ┆ 6810 │
# │ 2021            ┆ 5281 │
# │ 2018            ┆ 5886 │
# │ 2019            ┆ 5938 │
# │ 2025            ┆ 4549 │
# │ 2022            ┆ 5889 │
# └─────────────────┴──────┘

# %%
match_results_filtered = match_results.filter(
    ~pl.col("MatchURL").str.contains("History"),
    ~pl.col("Notes").fill_null("").str.contains("Cancelled"),
    ~pl.col("MatchURL").str.contains("RelegationPromotion-Play-offs"),
)

# %%
match_results_filtered.with_columns(missing_cond=missing_cond).filter(pl.col("Season_End_Year") >= 2025).filter(pl.col("missing_cond"))
# Out:
# shape: (1_130, 26)
# ┌────────────┬────────┬─────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ Competitio ┆ Gender ┆ Country ┆ Season_End ┆ … ┆ InMatchSum ┆ InTeamSumm ┆ InTeamAdv ┆ missing_c │
# │ n_Name     ┆ ---    ┆ ---     ┆ _Year      ┆   ┆ mary       ┆ ary        ┆ anced     ┆ ond       │
# │ ---        ┆ str    ┆ str     ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │ str        ┆        ┆         ┆ i64        ┆   ┆ bool       ┆ bool       ┆ bool      ┆ bool      │
# ╞════════════╪════════╪═════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ EFL Champi ┆ M      ┆ ENG     ┆ 2025       ┆ … ┆ false      ┆ false      ┆ false     ┆ true      │
# │ onship     ┆        ┆         ┆            ┆   ┆            ┆            ┆           ┆           │
# │ EFL Champi ┆ M      ┆ ENG     ┆ 2025       ┆ … ┆ false      ┆ false      ┆ false     ┆ true      │
# │ onship     ┆        ┆         ┆            ┆   ┆            ┆            ┆           ┆           │
# │ EFL Champi ┆ M      ┆ ENG     ┆ 2025       ┆ … ┆ false      ┆ false      ┆ false     ┆ true      │
# │ onship     ┆        ┆         ┆            ┆   ┆            ┆            ┆           ┆           │
# │ EFL Champi ┆ M      ┆ ENG     ┆ 2025       ┆ … ┆ false      ┆ false      ┆ false     ┆ true      │
# │ onship     ┆        ┆         ┆            ┆   ┆            ┆            ┆           ┆           │
# │ EFL Champi ┆ M      ┆ ENG     ┆ 2025       ┆ … ┆ false      ┆ false      ┆ false     ┆ true      │
# │ onship     ┆        ┆         ┆            ┆   ┆            ┆            ┆           ┆           │
# │ …          ┆ …      ┆ …       ┆ …          ┆ … ┆ …          ┆ …          ┆ …         ┆ …         │
# │ Serie A    ┆ M      ┆ ITA     ┆ 2025       ┆ … ┆ false      ┆ false      ┆ false     ┆ true      │
# │ Serie A    ┆ M      ┆ ITA     ┆ 2025       ┆ … ┆ false      ┆ false      ┆ false     ┆ true      │
# │ Serie A    ┆ M      ┆ ITA     ┆ 2025       ┆ … ┆ false      ┆ false      ┆ false     ┆ true      │
# │ Serie A    ┆ M      ┆ ITA     ┆ 2025       ┆ … ┆ false      ┆ false      ┆ false     ┆ true      │
# │ Serie A    ┆ M      ┆ ITA     ┆ 2025       ┆ … ┆ false      ┆ false      ┆ false     ┆ true      │
# └────────────┴────────┴─────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
match_summaries.filter(pl.col("Season_End_Year")>=2025).group_by("Country", "Tier", "Season_End_Year").len()
# Out:
# shape: (8, 4)
# ┌─────────┬──────┬─────────────────┬──────┐
# │ Country ┆ Tier ┆ Season_End_Year ┆ len  │
# │ ---     ┆ ---  ┆ ---             ┆ ---  │
# │ str     ┆ str  ┆ i64             ┆ u32  │
# ╞═════════╪══════╪═════════════════╪══════╡
# │ FRA     ┆ 1st  ┆ 2025            ┆ 2413 │
# │ ENG     ┆ 1st  ┆ 2025            ┆ 2148 │
# │ ENG     ┆ 3rd  ┆ 2025            ┆ 4517 │
# │ ITA     ┆ 1st  ┆ 2025            ┆ 3241 │
# │ GER     ┆ 1st  ┆ 2025            ┆ 2899 │
# │ ENG     ┆ 2nd  ┆ 2025            ┆ 6029 │
# │ ESP     ┆ 1st  ┆ 2025            ┆ 3348 │
# │ USA     ┆ 1st  ┆ 2025            ┆ 4790 │
# └─────────┴──────┴─────────────────┴──────┘

# %%
match_results.filter(pl.col("Season_End_Year")>=2025,
    # ~pl.col("MatchURL").str.contains("History"),
    ~pl.col("Notes").fill_null("").str.contains("Cancelled"),
    # ~pl.col("MatchURL").str.contains("RelegationPromotion-Play-offs"),
).filter(pl.col("Date")>"2025-01-10")
# Out:
# shape: (2_439, 22)
# ┌─────────────┬────────┬─────────┬─────────────┬───┬─────────────┬───────┬────────────┬────────────┐
# │ Competition ┆ Gender ┆ Country ┆ Season_End_ ┆ … ┆ Referee     ┆ Notes ┆ MatchURL   ┆ Min_Advanc │
# │ _Name       ┆ ---    ┆ ---     ┆ Year        ┆   ┆ ---         ┆ ---   ┆ ---        ┆ ed_Season  │
# │ ---         ┆ str    ┆ str     ┆ ---         ┆   ┆ str         ┆ str   ┆ str        ┆ ---        │
# │ str         ┆        ┆         ┆ i64         ┆   ┆             ┆       ┆            ┆ i64        │
# ╞═════════════╪════════╪═════════╪═════════════╪═══╪═════════════╪═══════╪════════════╪════════════╡
# │ EFL Champio ┆ M      ┆ ENG     ┆ 2025        ┆ … ┆ Samuel      ┆ null  ┆ https://fb ┆ 2019       │
# │ nship       ┆        ┆         ┆             ┆   ┆ Allison     ┆       ┆ ref.com/en ┆            │
# │             ┆        ┆         ┆             ┆   ┆             ┆       ┆ /matches/2 ┆            │
# │             ┆        ┆         ┆             ┆   ┆             ┆       ┆ …          ┆            │
# │ EFL Champio ┆ M      ┆ ENG     ┆ 2025        ┆ … ┆ Oliver      ┆ null  ┆ https://fb ┆ 2019       │
# │ nship       ┆        ┆         ┆             ┆   ┆ Langford    ┆       ┆ ref.com/en ┆            │
# │             ┆        ┆         ┆             ┆   ┆             ┆       ┆ /matches/3 ┆            │
# │             ┆        ┆         ┆             ┆   ┆             ┆       ┆ …          ┆            │
# │ EFL Champio ┆ M      ┆ ENG     ┆ 2025        ┆ … ┆ Farai       ┆ null  ┆ https://fb ┆ 2019       │
# │ nship       ┆        ┆         ┆             ┆   ┆ Hallam      ┆       ┆ ref.com/en ┆            │
# │             ┆        ┆         ┆             ┆   ┆             ┆       ┆ /matches/0 ┆            │
# │             ┆        ┆         ┆             ┆   ┆             ┆       ┆ …          ┆            │
# │ EFL Champio ┆ M      ┆ ENG     ┆ 2025        ┆ … ┆ Anthony     ┆ null  ┆ https://fb ┆ 2019       │
# │ nship       ┆        ┆         ┆             ┆   ┆ Backhouse   ┆       ┆ ref.com/en ┆            │
# │             ┆        ┆         ┆             ┆   ┆             ┆       ┆ /matches/2 ┆            │
# │             ┆        ┆         ┆             ┆   ┆             ┆       ┆ …          ┆            │
# │ EFL Champio ┆ M      ┆ ENG     ┆ 2025        ┆ … ┆ Stephen     ┆ null  ┆ https://fb ┆ 2019       │
# │ nship       ┆        ┆         ┆             ┆   ┆ Martin      ┆       ┆ ref.com/en ┆            │
# │             ┆        ┆         ┆             ┆   ┆             ┆       ┆ /matches/2 ┆            │
# │             ┆        ┆         ┆             ┆   ┆             ┆       ┆ …          ┆            │
# │ …           ┆ …      ┆ …       ┆ …           ┆ … ┆ …           ┆ …     ┆ …          ┆ …          │
# │ Major       ┆ M      ┆ USA     ┆ 2025        ┆ … ┆ null        ┆ null  ┆ https://fb ┆ 2018       │
# │ League      ┆        ┆         ┆             ┆   ┆             ┆       ┆ ref.com/en ┆            │
# │ Soccer      ┆        ┆         ┆             ┆   ┆             ┆       ┆ /stathead/ ┆            │
# │             ┆        ┆         ┆             ┆   ┆             ┆       ┆ …          ┆            │
# │ Major       ┆ M      ┆ USA     ┆ 2025        ┆ … ┆ null        ┆ null  ┆ https://fb ┆ 2018       │
# │ League      ┆        ┆         ┆             ┆   ┆             ┆       ┆ ref.com/en ┆            │
# │ Soccer      ┆        ┆         ┆             ┆   ┆             ┆       ┆ /stathead/ ┆            │
# │             ┆        ┆         ┆             ┆   ┆             ┆       ┆ …          ┆            │
# │ Major       ┆ M      ┆ USA     ┆ 2025        ┆ … ┆ null        ┆ null  ┆ https://fb ┆ 2018       │
# │ League      ┆        ┆         ┆             ┆   ┆             ┆       ┆ ref.com/en ┆            │
# │ Soccer      ┆        ┆         ┆             ┆   ┆             ┆       ┆ /stathead/ ┆            │
# │             ┆        ┆         ┆             ┆   ┆             ┆       ┆ …          ┆            │
# │ Major       ┆ M      ┆ USA     ┆ 2025        ┆ … ┆ null        ┆ null  ┆ https://fb ┆ 2018       │
# │ League      ┆        ┆         ┆             ┆   ┆             ┆       ┆ ref.com/en ┆            │
# │ Soccer      ┆        ┆         ┆             ┆   ┆             ┆       ┆ /stathead/ ┆            │
# │             ┆        ┆         ┆             ┆   ┆             ┆       ┆ …          ┆            │
# │ Major       ┆ M      ┆ USA     ┆ 2025        ┆ … ┆ null        ┆ null  ┆ https://fb ┆ 2018       │
# │ League      ┆        ┆         ┆             ┆   ┆             ┆       ┆ ref.com/en ┆            │
# │ Soccer      ┆        ┆         ┆             ┆   ┆             ┆       ┆ /stathead/ ┆            │
# │             ┆        ┆         ┆             ┆   ┆             ┆       ┆ …          ┆            │
# └─────────────┴────────┴─────────┴─────────────┴───┴─────────────┴───────┴────────────┴────────────┘

# %%
competitions = pl.read_csv(Path(BASE_DIR) / "competitions.csv").filter(pl.col("season_end_year") == 2025)

# %%
match_results = match_results.with_columns(CorrectURL=~pl.col("MatchURL").str.contains("History"))

match_results.filter(pl.col("Season_End_Year") == 2025).with_columns(Date=pl.col("Date").cast(pl.Date)).group_by("Date").agg(pl.col("CorrectURL").mean().alias("CorrectURL")).plot.line("Date","CorrectURL")
# Out:
# alt.Chart(...)

# %%
match_results.filter(~pl.col("CorrectURL"))
# Out:
# shape: (2_243, 23)
# ┌─────────────┬────────┬─────────┬─────────────┬───┬───────┬─────────────┬────────────┬────────────┐
# │ Competition ┆ Gender ┆ Country ┆ Season_End_ ┆ … ┆ Notes ┆ MatchURL    ┆ Min_Advanc ┆ CorrectURL │
# │ _Name       ┆ ---    ┆ ---     ┆ Year        ┆   ┆ ---   ┆ ---         ┆ ed_Season  ┆ ---        │
# │ ---         ┆ str    ┆ str     ┆ ---         ┆   ┆ str   ┆ str         ┆ ---        ┆ bool       │
# │ str         ┆        ┆         ┆ i64         ┆   ┆       ┆             ┆ i64        ┆            │
# ╞═════════════╪════════╪═════════╪═════════════╪═══╪═══════╪═════════════╪════════════╪════════════╡
# │ EFL Champio ┆ M      ┆ ENG     ┆ 2025        ┆ … ┆ null  ┆ https://fbr ┆ 2019       ┆ false      │
# │ nship       ┆        ┆         ┆             ┆   ┆       ┆ ef.com/en/s ┆            ┆            │
# │             ┆        ┆         ┆             ┆   ┆       ┆ tathead/…   ┆            ┆            │
# │ EFL Champio ┆ M      ┆ ENG     ┆ 2025        ┆ … ┆ null  ┆ https://fbr ┆ 2019       ┆ false      │
# │ nship       ┆        ┆         ┆             ┆   ┆       ┆ ef.com/en/s ┆            ┆            │
# │             ┆        ┆         ┆             ┆   ┆       ┆ tathead/…   ┆            ┆            │
# │ EFL Champio ┆ M      ┆ ENG     ┆ 2025        ┆ … ┆ null  ┆ https://fbr ┆ 2019       ┆ false      │
# │ nship       ┆        ┆         ┆             ┆   ┆       ┆ ef.com/en/s ┆            ┆            │
# │             ┆        ┆         ┆             ┆   ┆       ┆ tathead/…   ┆            ┆            │
# │ EFL Champio ┆ M      ┆ ENG     ┆ 2025        ┆ … ┆ null  ┆ https://fbr ┆ 2019       ┆ false      │
# │ nship       ┆        ┆         ┆             ┆   ┆       ┆ ef.com/en/s ┆            ┆            │
# │             ┆        ┆         ┆             ┆   ┆       ┆ tathead/…   ┆            ┆            │
# │ EFL Champio ┆ M      ┆ ENG     ┆ 2025        ┆ … ┆ null  ┆ https://fbr ┆ 2019       ┆ false      │
# │ nship       ┆        ┆         ┆             ┆   ┆       ┆ ef.com/en/s ┆            ┆            │
# │             ┆        ┆         ┆             ┆   ┆       ┆ tathead/…   ┆            ┆            │
# │ …           ┆ …      ┆ …       ┆ …           ┆ … ┆ …     ┆ …           ┆ …          ┆ …          │
# │ Major       ┆ M      ┆ USA     ┆ 2025        ┆ … ┆ null  ┆ https://fbr ┆ 2018       ┆ false      │
# │ League      ┆        ┆         ┆             ┆   ┆       ┆ ef.com/en/s ┆            ┆            │
# │ Soccer      ┆        ┆         ┆             ┆   ┆       ┆ tathead/…   ┆            ┆            │
# │ Major       ┆ M      ┆ USA     ┆ 2025        ┆ … ┆ null  ┆ https://fbr ┆ 2018       ┆ false      │
# │ League      ┆        ┆         ┆             ┆   ┆       ┆ ef.com/en/s ┆            ┆            │
# │ Soccer      ┆        ┆         ┆             ┆   ┆       ┆ tathead/…   ┆            ┆            │
# │ Major       ┆ M      ┆ USA     ┆ 2025        ┆ … ┆ null  ┆ https://fbr ┆ 2018       ┆ false      │
# │ League      ┆        ┆         ┆             ┆   ┆       ┆ ef.com/en/s ┆            ┆            │
# │ Soccer      ┆        ┆         ┆             ┆   ┆       ┆ tathead/…   ┆            ┆            │
# │ Major       ┆ M      ┆ USA     ┆ 2025        ┆ … ┆ null  ┆ https://fbr ┆ 2018       ┆ false      │
# │ League      ┆        ┆         ┆             ┆   ┆       ┆ ef.com/en/s ┆            ┆            │
# │ Soccer      ┆        ┆         ┆             ┆   ┆       ┆ tathead/…   ┆            ┆            │
# │ Major       ┆ M      ┆ USA     ┆ 2025        ┆ … ┆ null  ┆ https://fbr ┆ 2018       ┆ false      │
# │ League      ┆        ┆         ┆             ┆   ┆       ┆ ef.com/en/s ┆            ┆            │
# │ Soccer      ┆        ┆         ┆             ┆   ┆       ┆ tathead/…   ┆            ┆            │
# └─────────────┴────────┴─────────┴─────────────┴───┴───────┴─────────────┴────────────┴────────────┘

# %%
df = pl.read_csv("/home/jimmy/Code/FantasyFootball/data/ingest/fbref/match_summary/ENG_M_5th_match_summary_fbref_0001.csv")

# %%
df
# Out:
# shape: (4_864, 33)
# ┌──────────────┬──────────┬────────────┬──────────────┬───┬────────┬─────────┬──────┬──────────────┐
# │ MatchURL     ┆ League   ┆ Match_Date ┆ Matchweek    ┆ … ┆ Gender ┆ Country ┆ Tier ┆ Season_End_Y │
# │ ---          ┆ ---      ┆ ---        ┆ ---          ┆   ┆ ---    ┆ ---     ┆ ---  ┆ ear          │
# │ str          ┆ str      ┆ str        ┆ str          ┆   ┆ str    ┆ str     ┆ str  ┆ ---          │
# │              ┆          ┆            ┆              ┆   ┆        ┆         ┆      ┆ i64          │
# ╞══════════════╪══════════╪════════════╪══════════════╪═══╪════════╪═════════╪══════╪══════════════╡
# │ https://fbre ┆ National ┆ 2018-05-05 ┆ National     ┆ … ┆ M      ┆ ENG     ┆ 5th  ┆ 2018         │
# │ f.com/en/mat ┆ League   ┆            ┆ League (Semi ┆   ┆        ┆         ┆      ┆              │
# │ ches/0…      ┆          ┆            ┆ -finals)     ┆   ┆        ┆         ┆      ┆              │
# │ https://fbre ┆ National ┆ 2018-05-05 ┆ National     ┆ … ┆ M      ┆ ENG     ┆ 5th  ┆ 2018         │
# │ f.com/en/mat ┆ League   ┆            ┆ League (Semi ┆   ┆        ┆         ┆      ┆              │
# │ ches/0…      ┆          ┆            ┆ -finals)     ┆   ┆        ┆         ┆      ┆              │
# │ https://fbre ┆ National ┆ 2018-05-05 ┆ National     ┆ … ┆ M      ┆ ENG     ┆ 5th  ┆ 2018         │
# │ f.com/en/mat ┆ League   ┆            ┆ League (Semi ┆   ┆        ┆         ┆      ┆              │
# │ ches/0…      ┆          ┆            ┆ -finals)     ┆   ┆        ┆         ┆      ┆              │
# │ https://fbre ┆ National ┆ 2018-05-05 ┆ National     ┆ … ┆ M      ┆ ENG     ┆ 5th  ┆ 2018         │
# │ f.com/en/mat ┆ League   ┆            ┆ League (Semi ┆   ┆        ┆         ┆      ┆              │
# │ ches/0…      ┆          ┆            ┆ -finals)     ┆   ┆        ┆         ┆      ┆              │
# │ https://fbre ┆ National ┆ 2018-05-05 ┆ National     ┆ … ┆ M      ┆ ENG     ┆ 5th  ┆ 2018         │
# │ f.com/en/mat ┆ League   ┆            ┆ League (Semi ┆   ┆        ┆         ┆      ┆              │
# │ ches/0…      ┆          ┆            ┆ -finals)     ┆   ┆        ┆         ┆      ┆              │
# │ …            ┆ …        ┆ …          ┆ …            ┆ … ┆ …      ┆ …       ┆ …    ┆ …            │
# │ https://fbre ┆ National ┆ 2019-05-05 ┆ National     ┆ … ┆ M      ┆ ENG     ┆ 5th  ┆ 2019         │
# │ f.com/en/mat ┆ League   ┆            ┆ League (Semi ┆   ┆        ┆         ┆      ┆              │
# │ ches/4…      ┆          ┆            ┆ -finals)     ┆   ┆        ┆         ┆      ┆              │
# │ https://fbre ┆ National ┆ 2019-05-05 ┆ National     ┆ … ┆ M      ┆ ENG     ┆ 5th  ┆ 2019         │
# │ f.com/en/mat ┆ League   ┆            ┆ League (Semi ┆   ┆        ┆         ┆      ┆              │
# │ ches/4…      ┆          ┆            ┆ -finals)     ┆   ┆        ┆         ┆      ┆              │
# │ https://fbre ┆ National ┆ 2019-05-05 ┆ National     ┆ … ┆ M      ┆ ENG     ┆ 5th  ┆ 2019         │
# │ f.com/en/mat ┆ League   ┆            ┆ League (Semi ┆   ┆        ┆         ┆      ┆              │
# │ ches/4…      ┆          ┆            ┆ -finals)     ┆   ┆        ┆         ┆      ┆              │
# │ https://fbre ┆ National ┆ 2019-05-05 ┆ National     ┆ … ┆ M      ┆ ENG     ┆ 5th  ┆ 2019         │
# │ f.com/en/mat ┆ League   ┆            ┆ League (Semi ┆   ┆        ┆         ┆      ┆              │
# │ ches/4…      ┆          ┆            ┆ -finals)     ┆   ┆        ┆         ┆      ┆              │
# │ https://fbre ┆ National ┆ 2019-05-05 ┆ National     ┆ … ┆ M      ┆ ENG     ┆ 5th  ┆ 2019         │
# │ f.com/en/mat ┆ League   ┆            ┆ League (Semi ┆   ┆        ┆         ┆      ┆              │
# │ ches/4…      ┆          ┆            ┆ -finals)     ┆   ┆        ┆         ┆      ┆              │
# └──────────────┴──────────┴────────────┴──────────────┴───┴────────┴─────────┴──────┴──────────────┘

# %%
match_results.filter(pl.col("Season_End_Year") == 2025).with_columns(Date=pl.col("Date").cast(pl.Date).dt.month_end()).group_by("Date").agg(pl.col("CorrectURL").mean().alias("CorrectURL"))
# Out:
# shape: (15, 2)
# ┌────────────┬────────────┐
# │ Date       ┆ CorrectURL │
# │ ---        ┆ ---        │
# │ date       ┆ f64        │
# ╞════════════╪════════════╡
# │ 2025-06-30 ┆ 0.0        │
# │ 2024-11-30 ┆ 1.0        │
# │ 2025-04-30 ┆ 0.0        │
# │ 2025-03-31 ┆ 0.0        │
# │ 2024-12-31 ┆ 1.0        │
# │ …          ┆ …          │
# │ 2025-05-31 ┆ 0.0        │
# │ 2025-01-31 ┆ 0.65311    │
# │ 2025-07-31 ┆ 0.0        │
# │ 2025-09-30 ┆ 0.0        │
# │ 2024-10-31 ┆ 1.0        │
# └────────────┴────────────┘

# %%
match_results.filter(pl.col("Season_End_Year")>=2025).filter(~pl.col("CorrectURL"))
# Out:
# shape: (2_243, 23)
# ┌─────────────┬────────┬─────────┬─────────────┬───┬───────┬─────────────┬────────────┬────────────┐
# │ Competition ┆ Gender ┆ Country ┆ Season_End_ ┆ … ┆ Notes ┆ MatchURL    ┆ Min_Advanc ┆ CorrectURL │
# │ _Name       ┆ ---    ┆ ---     ┆ Year        ┆   ┆ ---   ┆ ---         ┆ ed_Season  ┆ ---        │
# │ ---         ┆ str    ┆ str     ┆ ---         ┆   ┆ str   ┆ str         ┆ ---        ┆ bool       │
# │ str         ┆        ┆         ┆ i64         ┆   ┆       ┆             ┆ i64        ┆            │
# ╞═════════════╪════════╪═════════╪═════════════╪═══╪═══════╪═════════════╪════════════╪════════════╡
# │ EFL Champio ┆ M      ┆ ENG     ┆ 2025        ┆ … ┆ null  ┆ https://fbr ┆ 2019       ┆ false      │
# │ nship       ┆        ┆         ┆             ┆   ┆       ┆ ef.com/en/s ┆            ┆            │
# │             ┆        ┆         ┆             ┆   ┆       ┆ tathead/…   ┆            ┆            │
# │ EFL Champio ┆ M      ┆ ENG     ┆ 2025        ┆ … ┆ null  ┆ https://fbr ┆ 2019       ┆ false      │
# │ nship       ┆        ┆         ┆             ┆   ┆       ┆ ef.com/en/s ┆            ┆            │
# │             ┆        ┆         ┆             ┆   ┆       ┆ tathead/…   ┆            ┆            │
# │ EFL Champio ┆ M      ┆ ENG     ┆ 2025        ┆ … ┆ null  ┆ https://fbr ┆ 2019       ┆ false      │
# │ nship       ┆        ┆         ┆             ┆   ┆       ┆ ef.com/en/s ┆            ┆            │
# │             ┆        ┆         ┆             ┆   ┆       ┆ tathead/…   ┆            ┆            │
# │ EFL Champio ┆ M      ┆ ENG     ┆ 2025        ┆ … ┆ null  ┆ https://fbr ┆ 2019       ┆ false      │
# │ nship       ┆        ┆         ┆             ┆   ┆       ┆ ef.com/en/s ┆            ┆            │
# │             ┆        ┆         ┆             ┆   ┆       ┆ tathead/…   ┆            ┆            │
# │ EFL Champio ┆ M      ┆ ENG     ┆ 2025        ┆ … ┆ null  ┆ https://fbr ┆ 2019       ┆ false      │
# │ nship       ┆        ┆         ┆             ┆   ┆       ┆ ef.com/en/s ┆            ┆            │
# │             ┆        ┆         ┆             ┆   ┆       ┆ tathead/…   ┆            ┆            │
# │ …           ┆ …      ┆ …       ┆ …           ┆ … ┆ …     ┆ …           ┆ …          ┆ …          │
# │ Major       ┆ M      ┆ USA     ┆ 2025        ┆ … ┆ null  ┆ https://fbr ┆ 2018       ┆ false      │
# │ League      ┆        ┆         ┆             ┆   ┆       ┆ ef.com/en/s ┆            ┆            │
# │ Soccer      ┆        ┆         ┆             ┆   ┆       ┆ tathead/…   ┆            ┆            │
# │ Major       ┆ M      ┆ USA     ┆ 2025        ┆ … ┆ null  ┆ https://fbr ┆ 2018       ┆ false      │
# │ League      ┆        ┆         ┆             ┆   ┆       ┆ ef.com/en/s ┆            ┆            │
# │ Soccer      ┆        ┆         ┆             ┆   ┆       ┆ tathead/…   ┆            ┆            │
# │ Major       ┆ M      ┆ USA     ┆ 2025        ┆ … ┆ null  ┆ https://fbr ┆ 2018       ┆ false      │
# │ League      ┆        ┆         ┆             ┆   ┆       ┆ ef.com/en/s ┆            ┆            │
# │ Soccer      ┆        ┆         ┆             ┆   ┆       ┆ tathead/…   ┆            ┆            │
# │ Major       ┆ M      ┆ USA     ┆ 2025        ┆ … ┆ null  ┆ https://fbr ┆ 2018       ┆ false      │
# │ League      ┆        ┆         ┆             ┆   ┆       ┆ ef.com/en/s ┆            ┆            │
# │ Soccer      ┆        ┆         ┆             ┆   ┆       ┆ tathead/…   ┆            ┆            │
# │ Major       ┆ M      ┆ USA     ┆ 2025        ┆ … ┆ null  ┆ https://fbr ┆ 2018       ┆ false      │
# │ League      ┆        ┆         ┆             ┆   ┆       ┆ ef.com/en/s ┆            ┆            │
# │ Soccer      ┆        ┆         ┆             ┆   ┆       ┆ tathead/…   ┆            ┆            │
# └─────────────┴────────┴─────────┴─────────────┴───┴───────┴─────────────┴────────────┴────────────┘

# %%
match_results
# Out:
# shape: (149, 26)
# ┌────────────┬────────┬─────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ Competitio ┆ Gender ┆ Country ┆ Season_End ┆ … ┆ InMatchSum ┆ InTeamSumm ┆ InTeamAdv ┆ CorrectUR │
# │ n_Name     ┆ ---    ┆ ---     ┆ _Year      ┆   ┆ mary       ┆ ary        ┆ anced     ┆ L         │
# │ ---        ┆ str    ┆ str     ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │ str        ┆        ┆         ┆ i64        ┆   ┆ bool       ┆ bool       ┆ bool      ┆ bool      │
# ╞════════════╪════════╪═════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ EFL Champi ┆ M      ┆ ENG     ┆ 2018       ┆ … ┆ true       ┆ true       ┆ false     ┆ true      │
# │ onship     ┆        ┆         ┆            ┆   ┆            ┆            ┆           ┆           │
# │ EFL Champi ┆ M      ┆ ENG     ┆ 2018       ┆ … ┆ true       ┆ true       ┆ false     ┆ true      │
# │ onship     ┆        ┆         ┆            ┆   ┆            ┆            ┆           ┆           │
# │ EFL Champi ┆ M      ┆ ENG     ┆ 2018       ┆ … ┆ true       ┆ true       ┆ false     ┆ true      │
# │ onship     ┆        ┆         ┆            ┆   ┆            ┆            ┆           ┆           │
# │ EFL Champi ┆ M      ┆ ENG     ┆ 2018       ┆ … ┆ true       ┆ true       ┆ false     ┆ true      │
# │ onship     ┆        ┆         ┆            ┆   ┆            ┆            ┆           ┆           │
# │ EFL Champi ┆ M      ┆ ENG     ┆ 2019       ┆ … ┆ false      ┆ true       ┆ false     ┆ true      │
# │ onship     ┆        ┆         ┆            ┆   ┆            ┆            ┆           ┆           │
# │ …          ┆ …      ┆ …       ┆ …          ┆ … ┆ …          ┆ …          ┆ …         ┆ …         │
# │ Major      ┆ M      ┆ USA     ┆ 2023       ┆ … ┆ true       ┆ true       ┆ true      ┆ true      │
# │ League     ┆        ┆         ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Soccer     ┆        ┆         ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Major      ┆ M      ┆ USA     ┆ 2023       ┆ … ┆ true       ┆ true       ┆ true      ┆ true      │
# │ League     ┆        ┆         ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Soccer     ┆        ┆         ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Major      ┆ M      ┆ USA     ┆ 2023       ┆ … ┆ true       ┆ true       ┆ true      ┆ true      │
# │ League     ┆        ┆         ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Soccer     ┆        ┆         ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Major      ┆ M      ┆ USA     ┆ 2024       ┆ … ┆ true       ┆ true       ┆ true      ┆ true      │
# │ League     ┆        ┆         ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Soccer     ┆        ┆         ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Major      ┆ M      ┆ USA     ┆ 2024       ┆ … ┆ true       ┆ true       ┆ true      ┆ true      │
# │ League     ┆        ┆         ┆            ┆   ┆            ┆            ┆           ┆           │
# │ Soccer     ┆        ┆         ┆            ┆   ┆            ┆            ┆           ┆           │
# └────────────┴────────┴─────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
competitions
# Out:
# shape: (90, 16)
# ┌────────────┬────────────┬─────────┬────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ competitio ┆ competitio ┆ country ┆ gender ┆ … ┆ seasons_ur ┆ fixtures_u ┆ is_comple ┆ filter_ou │
# │ n_type     ┆ n_name     ┆ ---     ┆ ---    ┆   ┆ ls         ┆ rl         ┆ ted       ┆ t         │
# │ ---        ┆ ---        ┆ str     ┆ str    ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │ str        ┆ str        ┆         ┆        ┆   ┆ str        ┆ str        ┆ bool      ┆ str       │
# ╞════════════╪════════════╪═════════╪════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ Club Inter ┆ Copa Liber ┆ null    ┆ M      ┆ … ┆ https://fb ┆ https://fb ┆ false     ┆ N         │
# │ national   ┆ tadores de ┆         ┆        ┆   ┆ ref.com/en ┆ ref.com/en ┆           ┆           │
# │ Cups       ┆ América    ┆         ┆        ┆   ┆ /comps/14/ ┆ /comps/14/ ┆           ┆           │
# │            ┆            ┆         ┆        ┆   ┆ …          ┆ …          ┆           ┆           │
# │ Club Inter ┆ Copa       ┆ null    ┆ M      ┆ … ┆ https://fb ┆ https://fb ┆ false     ┆ N         │
# │ national   ┆ CONMEBOL   ┆         ┆        ┆   ┆ ref.com/en ┆ ref.com/en ┆           ┆           │
# │ Cups       ┆ Sudamerica ┆         ┆        ┆   ┆ /comps/205 ┆ /comps/205 ┆           ┆           │
# │            ┆ na         ┆         ┆        ┆   ┆ …          ┆ …          ┆           ┆           │
# │ Club Inter ┆ UEFA       ┆ null    ┆ M      ┆ … ┆ https://fb ┆ https://fb ┆ false     ┆ N         │
# │ national   ┆ Champions  ┆         ┆        ┆   ┆ ref.com/en ┆ ref.com/en ┆           ┆           │
# │ Cups       ┆ League     ┆         ┆        ┆   ┆ /comps/8/C ┆ /comps/8/s ┆           ┆           │
# │            ┆            ┆         ┆        ┆   ┆ …          ┆ …          ┆           ┆           │
# │ Club Inter ┆ UEFA       ┆ null    ┆ M      ┆ … ┆ https://fb ┆ https://fb ┆ false     ┆ N         │
# │ national   ┆ Europa     ┆         ┆        ┆   ┆ ref.com/en ┆ ref.com/en ┆           ┆           │
# │ Cups       ┆ League     ┆         ┆        ┆   ┆ /comps/19/ ┆ /comps/19/ ┆           ┆           │
# │            ┆            ┆         ┆        ┆   ┆ …          ┆ …          ┆           ┆           │
# │ Club Inter ┆ UEFA       ┆ null    ┆ M      ┆ … ┆ https://fb ┆ https://fb ┆ false     ┆ N         │
# │ national   ┆ Conference ┆         ┆        ┆   ┆ ref.com/en ┆ ref.com/en ┆           ┆           │
# │ Cups       ┆ League     ┆         ┆        ┆   ┆ /comps/882 ┆ /comps/882 ┆           ┆           │
# │            ┆            ┆         ┆        ┆   ┆ …          ┆ …          ┆           ┆           │
# │ …          ┆ …          ┆ …       ┆ …      ┆ … ┆ …          ┆ …          ┆ …         ┆ …         │
# │ Domestic   ┆ Coppa      ┆ ITA     ┆ M      ┆ … ┆ https://fb ┆ https://fb ┆ false     ┆ N         │
# │ Cups       ┆ Italia     ┆         ┆        ┆   ┆ ref.com/en ┆ ref.com/en ┆           ┆           │
# │            ┆            ┆         ┆        ┆   ┆ /comps/529 ┆ /comps/529 ┆           ┆           │
# │            ┆            ┆         ┆        ┆   ┆ …          ┆ …          ┆           ┆           │
# │ Domestic   ┆ Supercoppa ┆ ITA     ┆ M      ┆ … ┆ https://fb ┆ https://fb ┆ true      ┆ N         │
# │ Cups       ┆ Italiana   ┆         ┆        ┆   ┆ ref.com/en ┆ ref.com/en ┆           ┆           │
# │            ┆            ┆         ┆        ┆   ┆ /comps/612 ┆ /comps/612 ┆           ┆           │
# │            ┆            ┆         ┆        ┆   ┆ …          ┆ …          ┆           ┆           │
# │ Domestic   ┆ Premier    ┆ ENG     ┆ M      ┆ … ┆ https://fb ┆ https://fb ┆ false     ┆ N         │
# │ Youth      ┆ League 2   ┆         ┆        ┆   ┆ ref.com/en ┆ ref.com/en ┆           ┆           │
# │ Leagues    ┆            ┆         ┆        ┆   ┆ /comps/852 ┆ /comps/852 ┆           ┆           │
# │            ┆            ┆         ┆        ┆   ┆ …          ┆ …          ┆           ┆           │
# │ Domestic   ┆ U17 DFB    ┆ GER     ┆ M      ┆ … ┆ https://fb ┆ https://fb ┆ false     ┆ N         │
# │ Youth      ┆ Youth      ┆         ┆        ┆   ┆ ref.com/en ┆ ref.com/en ┆           ┆           │
# │ Leagues    ┆ League     ┆         ┆        ┆   ┆ /comps/851 ┆ /comps/851 ┆           ┆           │
# │            ┆            ┆         ┆        ┆   ┆ …          ┆ …          ┆           ┆           │
# │ Domestic   ┆ U19 DFB    ┆ GER     ┆ M      ┆ … ┆ https://fb ┆ https://fb ┆ false     ┆ N         │
# │ Youth      ┆ Youth      ┆         ┆        ┆   ┆ ref.com/en ┆ ref.com/en ┆           ┆           │
# │ Leagues    ┆ League     ┆         ┆        ┆   ┆ /comps/850 ┆ /comps/850 ┆           ┆           │
# │            ┆            ┆         ┆        ┆   ┆ …          ┆ …          ┆           ┆           │
# └────────────┴────────────┴─────────┴────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
match_summaries.filter(pl.col("Season_End_Year")==2025).group_by("Country", "Tier", "Season_End_Year").len()
# Out:
# shape: (8, 4)
# ┌─────────┬──────┬─────────────────┬──────┐
# │ Country ┆ Tier ┆ Season_End_Year ┆ len  │
# │ ---     ┆ ---  ┆ ---             ┆ ---  │
# │ str     ┆ str  ┆ i64             ┆ u32  │
# ╞═════════╪══════╪═════════════════╪══════╡
# │ ENG     ┆ 3rd  ┆ 2025            ┆ 4517 │
# │ ENG     ┆ 1st  ┆ 2025            ┆ 2148 │
# │ GER     ┆ 1st  ┆ 2025            ┆ 2899 │
# │ ENG     ┆ 2nd  ┆ 2025            ┆ 6029 │
# │ FRA     ┆ 1st  ┆ 2025            ┆ 2413 │
# │ ITA     ┆ 1st  ┆ 2025            ┆ 3241 │
# │ USA     ┆ 1st  ┆ 2025            ┆ 4790 │
# │ ESP     ┆ 1st  ┆ 2025            ┆ 3348 │
# └─────────┴──────┴─────────────────┴──────┘

# %%
import shutil

# %%
# new_files =list(Path(STAGE_DIR).glob("**/*.csv"))
# for f in new_files:
#     next_path = str(f).replace(STAGE_DIR, BASE_DIR)
#     existing_pattern = Path(next_path).with_name(f.name.replace("_fbref", "_fbref_*"))
#     # get the maximum 4 digit number in the existing files
#     existing_files = len([x for x in Path().glob(str(existing_pattern))]) + 1
#     new_name = Path(next_path).with_name(f.name.replace("_fbref", f"_fbref_{existing_files:>04}"))
#     shutil.move(f, new_name)

# %%
def r_to_python(r_obj):
    """Convert R object to Python object"""
    try:
        r('''
        unnest_list_columns <- function(df) {
            df <- tidyr::unnest(df, where(is.list), keep_empty = TRUE)
            return(df)
        }
        ''')
        r_obj = r.unnest_list_columns(r_obj)
        res = pandas2ri.rpy2py(r_obj)


        for c in res.columns:
            if res[c].dtype == "object":
                res[c] = res[c].str.replace("NA_character_", "")
        # if "MatchURL" in res.columns:
        #     if "Game_URL" in res.columns:
        #         res["MatchURL"] = res["Game_URL"]
        #     else:
        #         raise ValueError("URL not found")
        return pl.DataFrame(res)
    except Exception as e:
        # convert to list
        return r_obj

# %%
def get_wages(part_df):
    team_urls = call_wf_function(
        "fb_teams_urls", league_url=part_df["seasons_urls"].to_list()[0]
    )
    wages = []
    for url in track(team_urls, description="Getting wages"):
        try:
            w = call_wf_function("fb_squad_wages", team_urls=[str(url)], time_pause=4)
            # time.sleep(4)
            if w is not None:
                wages.append(w)
            else:
                log.error(f"No wages found for {url}")
        except Exception as e:
            log.error(f"Error getting wages for {url}: {e}")

    # wages = call_wf_function("fb_squad_wages", team_urls=team_urls, time_pause=4)
    wages = pl.concat(wages)
    return wages

# %%
    competitions = pl.read_csv(Path(BASE_DIR) / "competitions.csv").rename(
        {
            "country": "Country",
            "tier": "Tier",
            "season_end_year": "Season_End_Year",
            "gender": "Gender",
        }
    )
    tier_df = pl.DataFrame(LEAGUE_STATS)
    filtered_competitions = competitions.join(tier_df, on=["Country", "Tier"]).filter(
        pl.col("Season_End_Year") >= MIN_SEASON_END_YEAR, pl.col("Gender") == gender
    )
    league_parts = filtered_competitions.partition_by(
        ["Country", "Gender", "Tier", "Season_End_Year"], as_dict=True
    )
    for (country, gender, tier, season), part_df in league_parts.items():

        filename = (
            Path(STAGE_DIR)
            / "wages"
            / f"{country}_{gender}_{tier}_{SOURCE_SUFFIX}_{season}.csv"
        )
        if not filename.parent.exists():
            filename.parent.mkdir(parents=True, exist_ok=True)
        if filename.exists():
            continue
        print(f"Getting wages for {country} {tier} {season}")
        wages = get_wages(part_df)

        if wages is not None:
            wages.write_csv(filename)

# %%
w = [r_to_python(x) if not isinstance(x, pl.DataFrame) else x for x in wages]

# %%
w2 = pl.concat(w)

# %%
filename
# Out:
# PosixPath('data/ingest/stage/wages/ENG_M_1st_fbref_2018.csv')

# %%
w2.write_csv(filename)

# %%
r('''
unnest_list_columns <- function(df) {
    df <- tidyr::unnest(df, where(is.list), keep_empty = TRUE)
    return(df)
}
''')

rdf_exploded = r.unnest_list_columns(wages[-3])

# %%
print(wages[-3])
# Out:
# # A tibble: 36 × 15
#    Team       Comp  Season Player Nation Pos     Age WeeklyWageGBP WeeklyWageEUR
#    <chr>      <chr> <chr>  <chr>  <chr>  <chr> <int> <list>        <list>
#  1 Swansea C… Prem… 2017-… Wilfr… CIV    FW       28 <dbl [1]>     <dbl [1]>
#  2 Swansea C… Prem… 2017-… André… GHA    MF,FW    27 <dbl [1]>     <dbl [1]>
#  3 Swansea C… Prem… 2017-… Tammy… ENG    FW       19 <dbl [1]>     <dbl [1]>
#  4 Swansea C… Prem… 2017-… Sam C… ENG    MF       26 <dbl [1]>     <dbl [1]>
#  5 Swansea C… Prem… 2017-… Łukas… POL    GK       32 <dbl [1]>     <dbl [1]>
#  6 Swansea C… Prem… 2017-… Jorda… GHA    FW,MF    25 <dbl [1]>     <dbl [1]>
#  7 Swansea C… Prem… 2017-… Leroy… NED    MF       27 <dbl [1]>     <dbl [1]>
#  8 Swansea C… Prem… 2017-… Feder… ARG    DF       28 <dbl [1]>     <dbl [1]>
#  9 Swansea C… Prem… 2017-… Andy … WAL    MF       28 <dbl [1]>     <dbl [1]>
# 10 Swansea C… Prem… 2017-… Leon … ENG    MF       34 <dbl [1]>     <dbl [1]>
# # ℹ 26 more rows
# # ℹ 6 more variables: WeeklyWageUSD <list>, AnnualWageGBP <list>,
# #   AnnualWageEUR <list>, AnnualWageUSD <list>, Notes <chr>, Url <chr>
# # ℹ Use `print(n = ...)` to see more rows

# %%
print(rdf_exploded)
# Out:
# # A tibble: 37 × 15
#    Team       Comp  Season Player Nation Pos     Age WeeklyWageGBP WeeklyWageEUR
#    <chr>      <chr> <chr>  <chr>  <chr>  <chr> <int>         <dbl>         <dbl>
#  1 Swansea C… Prem… 2017-… Wilfr… CIV    FW       28         90000        103602
#  2 Swansea C… Prem… 2017-… André… GHA    MF,FW    27         80000         92091
#  3 Swansea C… Prem… 2017-… Tammy… ENG    FW       19         50000         57557
#  4 Swansea C… Prem… 2017-… Sam C… ENG    MF       26         50000         57557
#  5 Swansea C… Prem… 2017-… Łukas… POL    GK       32         50000         57557
#  6 Swansea C… Prem… 2017-… Jorda… GHA    FW,MF    25         50000         57557
#  7 Swansea C… Prem… 2017-… Leroy… NED    MF       27         45000         51801
#  8 Swansea C… Prem… 2017-… Feder… ARG    DF       28         43000         49499
#  9 Swansea C… Prem… 2017-… Andy … WAL    MF       28         40000         46045
# 10 Swansea C… Prem… 2017-… Leon … ENG    MF       34         37500         43168
# # ℹ 27 more rows
# # ℹ 6 more variables: WeeklyWageUSD <dbl>, AnnualWageGBP <dbl>,
# #   AnnualWageEUR <dbl>, AnnualWageUSD <dbl>, Notes <chr>, Url <chr>
# # ℹ Use `print(n = ...)` to see more rows

# %%
r_to_python(rdf_exploded)
# Out:
# shape: (37, 15)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Team      ┆ Comp      ┆ Season    ┆ Player    ┆ … ┆ AnnualWag ┆ AnnualWag ┆ Notes     ┆ Url      │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ eEUR      ┆ eUSD      ┆ ---       ┆ ---      │
# │ str       ┆ str       ┆ str       ┆ str       ┆   ┆ ---       ┆ ---       ┆ str       ┆ str      │
# │           ┆           ┆           ┆           ┆   ┆ f64       ┆ f64       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Swansea   ┆ Premier   ┆ 2017-2018 ┆ Wilfried  ┆ … ┆ 5.387307e ┆ 5.905244e ┆ Unverifie ┆ https:// │
# │ City      ┆ League    ┆           ┆ Bony      ┆   ┆ 6         ┆ 6         ┆ d estimat ┆ fbref.co │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ ion       ┆ m/en/pla │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ yers/6…  │
# │ Swansea   ┆ Premier   ┆ 2017-2018 ┆ André     ┆ … ┆ 4.788717e ┆ 5.249105e ┆ Unverifie ┆ https:// │
# │ City      ┆ League    ┆           ┆ Ayew      ┆   ┆ 6         ┆ 6         ┆ d estimat ┆ fbref.co │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ ion       ┆ m/en/pla │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ yers/5…  │
# │ Swansea   ┆ Premier   ┆ 2017-2018 ┆ Tammy     ┆ … ┆ 2.992948e ┆ 3.280691e ┆ Unverifie ┆ https:// │
# │ City      ┆ League    ┆           ┆ Abraham   ┆   ┆ 6         ┆ 6         ┆ d estimat ┆ fbref.co │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ ion       ┆ m/en/pla │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ yers/f…  │
# │ Swansea   ┆ Premier   ┆ 2017-2018 ┆ Sam       ┆ … ┆ 2.992948e ┆ 3.280691e ┆ Unverifie ┆ https:// │
# │ City      ┆ League    ┆           ┆ Clucas    ┆   ┆ 6         ┆ 6         ┆ d estimat ┆ fbref.co │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ ion       ┆ m/en/pla │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ yers/9…  │
# │ Swansea   ┆ Premier   ┆ 2017-2018 ┆ Łukasz    ┆ … ┆ 2.992948e ┆ 3.280691e ┆ Unverifie ┆ https:// │
# │ City      ┆ League    ┆           ┆ Fabiański ┆   ┆ 6         ┆ 6         ┆ d estimat ┆ fbref.co │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ ion       ┆ m/en/pla │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ yers/9…  │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ Swansea   ┆ Premier   ┆ 2017-2018 ┆ Roque     ┆ … ┆ null      ┆ null      ┆           ┆ https:// │
# │ City      ┆ League    ┆           ┆ Mesa      ┆   ┆           ┆           ┆           ┆ fbref.co │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ m/en/pla │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ yers/7…  │
# │ Swansea   ┆ Premier   ┆ 2017-2018 ┆ Oliver    ┆ … ┆ null      ┆ null      ┆           ┆ https:// │
# │ City      ┆ League    ┆           ┆ McBurnie  ┆   ┆           ┆           ┆           ┆ fbref.co │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ m/en/pla │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ yers/7…  │
# │ Swansea   ┆ Premier   ┆ 2017-2018 ┆ Joe Rodon ┆ … ┆ null      ┆ null      ┆           ┆ https:// │
# │ City      ┆ League    ┆           ┆           ┆   ┆           ┆           ┆           ┆ fbref.co │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ m/en/pla │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ yers/8…  │
# │ Swansea   ┆ Premier   ┆ 2017-2018 ┆ Adam King ┆ … ┆ null      ┆ null      ┆           ┆ https:// │
# │ City      ┆ League    ┆           ┆           ┆   ┆           ┆           ┆           ┆ fbref.co │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ m/en/pla │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ yers/7…  │
# │ Swansea   ┆ Premier   ┆ 2017-2018 ┆ Jay       ┆ … ┆ null      ┆ null      ┆           ┆ https:// │
# │ City      ┆ League    ┆           ┆ Fulton    ┆   ┆           ┆           ┆           ┆ fbref.co │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ m/en/pla │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ yers/4…  │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
pandas2ri.rpy2py(wages[-3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 pandas2ri.rpy2py(wages[-3])
#
# File /usr/lib/python3.12/functools.py:907, in singledispatch.<locals>.wrapper(*args, **kw)
#     903 if not args:
#     904     raise TypeError(f'{funcname} requires at least '
#     905                     '1 positional argument')
# --> 907 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/rpy2/robjects/pandas2ri.py:332, in rpy2py_dataframe(obj)
#     330 rpy2py = conversion.get_conversion().rpy2py
#     331 colnames_lst = []
# --> 332 od = OrderedDict(
#     333     (i, rpy2py(col) if isinstance(col, rinterface.SexpVector) else col)
#     334     for i, col in enumerate(_flatten_dataframe(obj, colnames_lst))
#     335 )
#     337 res = pandas.DataFrame.from_dict(od)
#     338 res.columns = tuple('.'.join(_) if isinstance(_, list) else _ for _ in colnames_lst)
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/rpy2/robjects/pandas2ri.py:334, in <genexpr>(.0)
#     330 rpy2py = conversion.get_conversion().rpy2py
#     331 colnames_lst = []
#     332 od = OrderedDict(
#     333     (i, rpy2py(col) if isinstance(col, rinterface.SexpVector) else col)
# --> 334     for i, col in enumerate(_flatten_dataframe(obj, colnames_lst))
#     335 )
#     337 res = pandas.DataFrame.from_dict(od)
#     338 res.columns = tuple('.'.join(_) if isinstance(_, list) else _ for _ in colnames_lst)
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/rpy2/robjects/pandas2ri.py:319, in _flatten_dataframe(obj, colnames_lst)
#     317 col = obj[i]
#     318 if isinstance(col, ListSexpVector):
# --> 319     _ = _records_to_columns(col)
#     320     colnames_lst.extend((n, subn) for subn in _.keys())
#     321     for subcol in _.values():
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/rpy2/robjects/pandas2ri.py:274, in _records_to_columns(obj)
#     272 for i, record in enumerate(obj_ri):
#     273     checknames = set()
# --> 274     for name in record.names:
#     275         if name in checknames:
#     276             raise ValueError(
#     277                 f'The record {i} has "{name}" duplicated.'
#     278             )
#
# TypeError: 'NULLType' object is not iterable

# %%
from rpy2.robjects import r

# Assuming `rdf` is your rpy2.robjects.vectors.DataFrame
# Replace the problematic column (assume it's named "col_with_lists")
r('''
convert_list_column <- function(df, col_name) {
    df[[col_name]] <- sapply(df[[col_name]], function(x) paste(x, collapse = ","))
    return(df)
}
''')

# Apply the R function to your dataframe
rdf_fixed = r.convert_list_column(wages[-3], "AnnualWageGBP")

# %%
d = wages[-3]

# %%
r_to_python(rdf_fixed)
# Out:
# <rpy2.robjects.vectors.DataFrame object at 0x7c24a70d96d0> [19]
# R classes: ('tbl_df', 'tbl', 'data.frame')
# [StrSexpVe..., StrSexpVe..., StrSexpVe..., StrSexpVe..., ..., ListSexpV..., ListSexpV..., StrSexpVe..., StrSexpVe...]
#   Team: <class 'numpy.ndarray'>
#   array(['Swansea City', 'Swansea City', 'Swansea City', 'Swansea City',
#        'Swansea City', 'Swansea City', 'Swansea City', 'Swansea City',
#        'Swansea City', 'Swansea City', 'Swansea City', 'Swansea City',
#        'Swansea City', 'Swansea City', 'Swansea City', 'Swansea City',
#        'Swansea City', 'Swansea City', 'Swansea City', 'Swansea City',
#        'Swansea City', 'Swansea City', 'Swansea City', 'Swansea City',
#        'Swansea City', 'Swansea City', 'Swansea City', 'Swansea City',
#        'Swansea City', 'Swansea City', 'Swansea City', 'Swansea City',
#        'Swansea City', 'Swansea City', 'Swansea City', 'Swansea City'],
#       dtype='<U12')
#   Comp: <class 'numpy.ndarray'>
#   array(['Premier League', 'Premier League', 'Premier League',
#        'Premier League', 'Premier League', 'Premier League',
#        'Premier League', 'Premier League', 'Premier League',
#        'Premier League', 'Premier League', 'Premier League',
#        'Premier League', 'Premier League', 'Premier League',
#        'Premier League', 'Premier League', 'Premier League',
#        'Premier League', 'Premier League', 'Premier League',
#        'Premier League', 'Premier League', 'Premier League',
#        'Premier League', 'Premier League', 'Premier League',
#        'Premier League', 'Premier League', 'Premier League',
#        'Premier League', 'Premier League', 'Premier League',
#        'Premier League', 'Premier League', 'Premier League'], dtype='<U14')
#   Season: <class 'numpy.ndarray'>
#   array(['2017-2018', '2017-2018', '2017-2018', '2017-2018', '2017-2018',
#        '2017-2018', '2017-2018', '2017-2018', '2017-2018', '2017-2018',
#        '2017-2018', '2017-2018', '2017-2018', '2017-2018', '2017-2018',
#        '2017-2018', '2017-2018', '2017-2018', '2017-2018', '2017-2018',
#        '2017-2018', '2017-2018', '2017-2018', '2017-2018', '2017-2018',
#        '2017-2018', '2017-2018', '2017-2018', '2017-2018', '2017-2018',
#        '2017-2018', '2017-2018', '2017-2018', '2017-2018', '2017-2018',
#        '2017-2018'], dtype='<U9')
#   Player: <class 'numpy.ndarray'>
#   array(['Wilfried Bony', 'André Ayew', 'Tammy Abraham', 'Sam Clucas',
#        'Łukasz Fabiański', 'Jordan Ayew', 'Leroy Fer',
#        'Federico Fernández', 'Andy King', 'Leon Britton',
#        'Wayne Routledge', 'Tom Carroll', 'Kyle Naughton', 'Martin Olsson',
#        'Àngel Rangel', 'Nathan Dyer', 'Luciano Narsingh', 'Kyle Bartley',
#        'Renato Sanches', 'Kristoffer Nordfeldt', 'Alfie Mawson',
#        'Erwin Mulder', 'Mike van der Hoorn', 'Connor Roberts',
#        'Kenji Gorré', 'Daniel James', 'Courtney Baker-Richardson',
#        'Adnan Maric', 'George Byers', 'Ki Sung-yueng', 'Matt Grimes',
#        'Roque Mesa', 'Oliver McBurnie', 'Joe Rodon', 'Adam King',
#        'Jay Fulton'], dtype='<U25')
# ...
# <rpy2.robjects.vectors.DataFrame object at 0x7c24a70d96d0> [19]
# R classes: ('tbl_df', 'tbl', 'data.frame')
# [StrSexpVe..., StrSexpVe..., StrSexpVe..., StrSexpVe..., ..., ListSexpV..., ListSexpV..., StrSexpVe..., StrSexpVe...]
# <rpy2.robjects.vectors.DataFrame object at 0x7c24a70d96d0> [19]
# R classes: ('tbl_df', 'tbl', 'data.frame')
# [StrSexpVe..., StrSexpVe..., StrSexpVe..., StrSexpVe..., ..., ListSexpV..., ListSexpV..., StrSexpVe..., StrSexpVe...]
#   WeeklyWageGBP: <class 'numpy.ndarray'>
#   array(['Unverified estimation', 'Unverified estimation',
#        'Unverified estimation', 'Unverified estimation',
#        'Unverified estimation', 'Unverified estimation',
#        'Unverified estimation', 'Unverified estimation',
#        'Unverified estimation', 'Unverified estimation',
#        'Unverified estimation', 'Unverified estimation',
#        'Unverified estimation', 'Unverified estimation',
#        'Unverified estimation', 'Unverified estimation',
#        'Unverified estimation', 'Unverified estimation',
#        'Unverified estimation', 'Unverified estimation',
#        'Unverified estimation', 'Unverified estimation',
#        'Unverified estimation', 'Unverified estimation',
#        'Unverified estimation', 'Unverified estimation',
#        'Unverified estimation', 'Unverified estimation',
#        'Unverified estimation', '', '', '', '', '', '', ''], dtype='<U21')
#   WeeklyWageEUR: <class 'numpy.ndarray'>
#   array(['https://fbref.com/en/players/61abe9b6/Wilfried-Bony',
#        'https://fbref.com/en/players/5dbefa9d/Andre-Ayew',
#        'https://fbref.com/en/players/f586779e/Tammy-Abraham',
#        'https://fbref.com/en/players/987718f5/Sam-Clucas',
#        'https://fbref.com/en/players/9328b835/Lukasz-Fabianski',
#        'https://fbref.com/en/players/da052c14/Jordan-Ayew',
#        'https://fbref.com/en/players/3cefa66a/Leroy-Fer',
#        'https://fbref.com/en/players/f25b010f/Federico-Fernandez',
#        'https://fbref.com/en/players/d790907f/Andy-King',
#        'https://fbref.com/en/players/b92dd711/Leon-Britton',
#        'https://fbref.com/en/players/1d387eee/Wayne-Routledge',
#        'https://fbref.com/en/players/5a1900a4/Tom-Carroll',
#        'https://fbref.com/en/players/e860c42f/Kyle-Naughton',
#        'https://fbref.com/en/players/2f72f79e/Martin-Olsson',
#        'https://fbref.com/en/players/93ee387c/Angel-Rangel',
#        'https://fbref.com/en/players/6dfd5af0/Nathan-Dyer',
#        'https://fbref.com/en/players/977ffc24/Luciano-Narsingh',
#        'https://fbref.com/en/players/18e96f64/Kyle-Bartley',
#        'https://fbref.com/en/players/032f894e/Renato-Sanches',
#        'https://fbref.com/en/players/78549904/Kristoffer-Nordfeldt',
#        'https://fbref.com/en/players/d368feb8/Alfie-Mawson',
#        'https://fbref.com/en/players/b3576b7c/Erwin-Mulder',
#        'https://fbref.com/en/players/25f50295/Mike-van-der-Hoorn',
#        'https://fbref.com/en/players/24fae784/Connor-Roberts',
#        'https://fbref.com/en/players/52d1a4c6/Kenji-Gorre',
#        'https://fbref.com/en/players/c931d9f9/Daniel-James',
#        'https://fbref.com/en/players/3e2edcd1/Courtney-Baker-Richardson',
#        'https://fbref.com/en/players/95241e48/Adnan-Maric',
#        'https://fbref.com/en/players/f4c20cb3/George-Byers',
#        'https://fbref.com/en/players/1d8c99b0/Ki-Sung-yueng',
#        'https://fbref.com/en/players/81a487b9/Matt-Grimes',
#        'https://fbref.com/en/players/7c4243d4/Roque-Mesa',
#        'https://fbref.com/en/players/78b8ac63/Oliver-McBurnie',
#        'https://fbref.com/en/players/8d62d31a/Joe-Rodon',
#        'https://fbref.com/en/players/73aad99a/Adam-King',
#        'https://fbref.com/en/players/434ad289/Jay-Fulton'], dtype='<U63')

# %%
wages[-3].to_csvfile("test.csv")
# Out:
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 wages[-3].to_csvfile("test.csv")
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/rpy2/robjects/vectors.py:1510, in DataFrame.to_csvfile(self, path, quote, sep, eol, na, dec, row_names, col_names, qmethod, append)
#    1508 col_names = cv.py2rpy(col_names)
#    1509 qmethod = cv.py2rpy(qmethod)
# -> 1510 res = self._write_table(
#    1511     self,
#    1512     **{'file': path,
#    1513        'quote': quote, 'sep': sep,
#    1514        'eol': eol, 'na': na, 'dec': dec,
#    1515        'row.names': row_names,
#    1516        'col.names': col_names, 'qmethod': qmethod,
#    1517        'append': append})
#    1518 return res
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/rpy2/rinterface_lib/conversion.py:45, in _cdata_res_to_rinterface.<locals>._(*args, **kwargs)
#      44 def _(*args, **kwargs):
# ---> 45     cdata = function(*args, **kwargs)
#      46     # TODO: test cdata is of the expected CType
#      47     return _cdata_to_rinterface(cdata)
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/rpy2/rinterface.py:869, in SexpClosure.__call__(self, *args, **kwargs)
#     862     res = rmemory.protect(
#     863         openrlib.rlib.R_tryEval(
#     864             call_r,
#     865             call_context.__sexp__._cdata,
#     866             error_occured)
#     867     )
#     868     if error_occured[0]:
# --> 869         raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     870 return res
#
# RRuntimeError: Error in (function (x, file = "", append = FALSE, quote = TRUE, sep = " ",  :
#   unimplemented type 'list' in 'EncodeElement'

# %%
help(wages[-3])
# Out:
# Help on DataFrame in module rpy2.robjects.vectors object:
#
# class DataFrame(ListVector)
#  |  DataFrame(obj, stringsasfactor=False, checknames=False)
#  |
#  |  R 'data.frame'.
#  |
#  |  Method resolution order:
#  |      DataFrame
#  |      ListVector
#  |      Vector
#  |      rpy2.robjects.robject.RObjectMixin
#  |      abc.ABC
#  |      rpy2.rinterface.ListSexpVector
#  |      rpy2.rinterface_lib.sexp.SexpVector
#  |      rpy2.rinterface_lib.sexp.Sexp
#  |      rpy2.rinterface_lib.sexp.SexpVectorAbstract
#  |      rpy2.rinterface_lib._rinterface_capi.SupportsSEXP
#  |      typing.Generic
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getitem__(self, i)
#  |
#  |  __init__(self, obj, stringsasfactor=False, checknames=False)
#  |      Create a new data frame.
#  |
#  |      :param obj: object inheriting from rpy2.rinterface.SexpVector,
#  |          or inheriting from TaggedList or a mapping name -> value
#  |      :param stringsasfactors: Boolean indicating whether vectors
#  |          of strings should be turned to vectors. Note that factors
#  |          will not be turned to string vectors.
#  |      :param checknames: Boolean indicating whether column names
#  |          should be transformed to R syntactically valid names.
#  |
#  |  cbind(self, *args, **kwargs)
#  |      bind objects as supplementary columns
#  |
#  |  head(self, *args, **kwargs)
#  |      Call the R generic 'head()'.
#  |
#  |  iter_column(self)
#  |      iterator across columns
#  |
#  |  iter_row(self)
#  |      iterator across rows
#  |
#  |  rbind(self, *args, **kwargs)
#  |      bind objects as supplementary rows
#  |
#  |  to_csvfile(self, path, quote=True, sep=',', eol='\n', na='NA', dec='.', row_names=True, col_names=True, qmethod='escape', append=False)
#  |      Save the data into a .csv file.
#  |
#  |      :param path         : string with a path
#  |      :param quote        : quote character
#  |      :param sep          : separator character
#  |      :param eol          : end-of-line character(s)
#  |      :param na           : string for missing values
#  |      :param dec          : string for decimal separator
#  |      :param row_names    : boolean (save row names, or not)
#  |      :param col_names    : boolean (save column names, or not)
#  |      :param comment_char : method to 'escape' special characters
#  |      :param append       : boolean (append if the file in the path is
#  |      already existing, or not)
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  from_csvfile(path, header=True, sep=',', quote='"', dec='.', row_names=<rpy2.rinterface._MissingArgType object at 0x7c252052dfd0> [1], col_names=<rpy2.rinterface._MissingArgType object at 0x7c252052dfd0> [1], fill=True, comment_char='', na_strings=[], as_is=False)
#  |      Create an instance from data in a .csv file.
#  |
#  |      :param path: string with a path
#  |      :param header: boolean (heading line with column names or not)
#  |      :param sep: separator character
#  |      :param quote: quote character
#  |      :param row_names: column name, or column index for column names
#  |         (warning: indexing starts at one in R)
#  |      :param fill: boolean (fill the lines when less entries than columns)
#  |      :param comment_char: comment character
#  |      :param na_strings: a list of strings which are interpreted to be NA
#  |         values
#  |      :param as_is: boolean (keep the columns of strings as such, or turn
#  |         them into factors)
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  ncol
#  |      Number of columns.
#  |      :rtype: integer
#  |
#  |  nrow
#  |      Number of rows.
#  |      :rtype: integer
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  colnames
#  |
#  |  rownames
#  |      Row names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  __annotations__ = {}
#  |
#  |  __parameters__ = ()
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from ListVector:
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from ListVector:
#  |
#  |  from_length(length)
#  |      Create a list of given length
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Vector:
#  |
#  |  __add__(self, x)
#  |
#  |  __repr_content__(self)
#  |
#  |  __setitem__(self, i, value)
#  |
#  |  items(self)
#  |      iterator on names and values
#  |
#  |  repr_format_elt(self, elt, max_width=12)
#  |
#  |  sample(self: collections.abc.Sized, n: int, replace: bool = False, probabilities: Optional[collections.abc.Sized] = None)
#  |      Draw a random sample of size n from the vector.
#  |
#  |      If 'replace' is True, the sampling is done with replacement.
#  |      The optional argument 'probabilities' can indicate sampling
#  |      probabilities.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Vector:
#  |
#  |  names
#  |      Names for the items in the vector.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from rpy2.robjects.robject.RObjectMixin:
#  |
#  |  __getstate__(self)
#  |      Helper for pickle.
#  |
#  |  __setstate__(self, state)
#  |
#  |  __str__(self)
#  |      Return str(self).
#  |
#  |  r_repr(self)
#  |      String representation for an object that can be
#  |      directly evaluated as R code.
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from rpy2.robjects.robject.RObjectMixin:
#  |
#  |  slots
#  |      Attributes of the underlying R object as a Python mapping.
#  |
#  |      The attributes can accessed and assigned by name (as if they
#  |      were in a Python `dict`).
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from rpy2.robjects.robject.RObjectMixin:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  rclass
#  |      R class for the object, stored as an R string vector.
#  |
#  |      When setting the rclass, the new value will be:
#  |
#  |      - wrapped in a Python tuple if a string (the R class
#  |        is a vector of strings, and this is made for convenience)
#  |      - wrapped in a StrSexpVector
#  |
#  |      Note that when setting the class R may make a copy of
#  |      the whole object (R is mostly a functional language).
#  |      If this must be avoided, and if the number of parent
#  |      classes before and after the change are compatible,
#  |      the class name can be changed in-place by replacing
#  |      vector elements.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from rpy2.robjects.robject.RObjectMixin:
#  |
#  |  __rname__ = None
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from rpy2.rinterface_lib.sexp.Sexp:
#  |
#  |  do_slot = _(*args, **kwargs) from rpy2.rinterface_lib.conversion._cdata_res_to_rinterface.<locals>
#  |
#  |  do_slot_assign(self, name: str, value) -> None
#  |
#  |  get_attrib = _(*args, **kwargs) from rpy2.rinterface_lib.conversion._cdata_res_to_rinterface.<locals>
#  |
#  |  list_attrs = _(*args, **kwargs) from rpy2.rinterface_lib.conversion._cdata_res_to_rinterface.<locals>
#  |
#  |  rsame(self, sexp) -> bool
#  |      # TODO: deprecate this (and implement __eq__) ?
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from rpy2.rinterface_lib.sexp.Sexp:
#  |
#  |  __sexp_refcount__
#  |      Count the number of independent Python references to
#  |      the underlying R object.
#  |
#  |  named
#  |
#  |  names_from_c_attribute
#  |
#  |  rid
#  |      ID of the underlying R object (memory address).
#  |
#  |  typeof
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from rpy2.rinterface_lib.sexp.Sexp:
#  |
#  |  __sexp__
#  |      Access to the underlying C pointer to the R object.
#  |
#  |      When assigning a new SexpCapsule to this attribute, the
#  |      R C-level type of the new capsule must be equal to the
#  |      type of the old capsule. A ValueError is raised otherwise.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from rpy2.rinterface_lib.sexp.SexpVectorAbstract:
#  |
#  |  __iter__(self) -> Iterator[Union[rpy2.rinterface_lib.sexp.Sexp, ~VT, Any]]
#  |
#  |  __len__(self) -> int
#  |
#  |  index(self, item: Any) -> int
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from rpy2.rinterface_lib.sexp.SexpVectorAbstract:
#  |
#  |  from_iterable = _(*args, **kwargs) from rpy2.rinterface_lib.conversion._cdata_res_to_rinterface.<locals>
#  |
#  |  from_memoryview = _(*args, **kwargs) from rpy2.rinterface_lib.conversion._cdata_res_to_rinterface.<locals>
#  |
#  |  from_object(obj) -> ~VT
#  |      Create an R vector/array from a Python object, if possible.
#  |
#  |      An exception :class:`ValueError` will be raised if not possible.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from rpy2.rinterface_lib.sexp.SexpVectorAbstract:
#  |
#  |  __orig_bases__ = (<class 'rpy2.rinterface_lib._rinterface_capi.Support...
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from typing.Generic:
#  |
#  |  __class_getitem__(...)
#  |      Parameterizes a generic class.
#  |
#  |      At least, parameterizing a generic class is the *main* thing this
#  |      method does. For example, for some generic class `Foo`, this is called
#  |      when we do `Foo[int]` - there, with `cls=Foo` and `params=int`.
#  |
#  |      However, note that this method is also called when defining generic
#  |      classes in the first place with `class Foo[T]: ...`.
#  |
#  |  __init_subclass__(...)
#  |      Function to initialize subclasses.

# %%
from bayesball.utils import r_to_python, pandas2ri

pandas2ri.rpy2py(wages[-3].get_column("wages"))

# r_to_python(wages[-3])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 3
#       1 from bayesball.utils import r_to_python, pandas2ri
# ----> 3 pandas2ri.rpy2py(wages[-3].get_column("wages"))
#       5 # r_to_python(wages[-3])
#
# AttributeError: 'DataFrame' object has no attribute 'get_column'

# %%
    existing_files = [x for x in Path().glob(str(Path(next_path).with_name(f.name.replace("_fbref", "_fbref_*"))))]
# Out:
# data/ingest/stage/match_shooting/USA_M_1st_match_shooting_fbref.csv
# data/ingest/fbref/match_shooting/USA_M_1st_match_shooting_fbref_0001.csv
# data/ingest/stage/match_summary/ENG_M_5th_match_summary_fbref.csv
# data/ingest/fbref/match_summary/ENG_M_5th_match_summary_fbref_0001.csv
# data/ingest/stage/match_summary/USA_M_1st_match_summary_fbref.csv
# data/ingest/fbref/match_summary/USA_M_1st_match_summary_fbref_0001.csv
# data/ingest/stage/match_summary/ENG_M_2nd_match_summary_fbref.csv
# data/ingest/fbref/match_summary/ENG_M_2nd_match_summary_fbref_0001.csv
# data/ingest/stage/match_summary/GER_M_1st_match_summary_fbref.csv
# data/ingest/fbref/match_summary/GER_M_1st_match_summary_fbref_0001.csv
# data/ingest/stage/match_summary/ENG_M_3rd_match_summary_fbref.csv
# data/ingest/fbref/match_summary/ENG_M_3rd_match_summary_fbref_0001.csv
# data/ingest/stage/match_summary/ENG_M_4th_match_summary_fbref.csv
# data/ingest/fbref/match_summary/ENG_M_4th_match_summary_fbref_0001.csv
# data/ingest/stage/match_summary/ITA_M_1st_match_summary_fbref.csv
# data/ingest/fbref/match_summary/ITA_M_1st_match_summary_fbref_0001.csv
# data/ingest/stage/advanced_match_stats/team/misc/USA_M_1st_fbref.csv
# data/ingest/fbref/advanced_match_stats/team/misc/USA_M_1st_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/team/passing_types/USA_M_1st_fbref.csv
# data/ingest/fbref/advanced_match_stats/team/passing_types/USA_M_1st_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/team/passing/USA_M_1st_fbref.csv
# data/ingest/fbref/advanced_match_stats/team/passing/USA_M_1st_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/team/defense/USA_M_1st_fbref.csv
# data/ingest/fbref/advanced_match_stats/team/defense/USA_M_1st_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/team/summary/ENG_M_3rd_fbref.csv
# data/ingest/fbref/advanced_match_stats/team/summary/ENG_M_3rd_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/team/summary/ENG_M_2nd_fbref.csv
# data/ingest/fbref/advanced_match_stats/team/summary/ENG_M_2nd_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/team/summary/ENG_M_4th_fbref.csv
# data/ingest/fbref/advanced_match_stats/team/summary/ENG_M_4th_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/team/summary/GER_M_1st_fbref.csv
# data/ingest/fbref/advanced_match_stats/team/summary/GER_M_1st_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/team/summary/ENG_M_5th_fbref.csv
# data/ingest/fbref/advanced_match_stats/team/summary/ENG_M_5th_fbref_0001.csv
# data/ingest/stage/advanced_match_stats/team/summary/ITA_M_1st_fbref.csv
# data/ingest/fbref/advanced_match_stats/team/summary/ITA_M_1st_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/team/summary/USA_M_1st_fbref.csv
# data/ingest/fbref/advanced_match_stats/team/summary/USA_M_1st_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/team/possession/USA_M_1st_fbref.csv
# data/ingest/fbref/advanced_match_stats/team/possession/USA_M_1st_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/team/keeper/GER_M_1st_fbref.csv
# data/ingest/fbref/advanced_match_stats/team/keeper/GER_M_1st_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/team/keeper/ITA_M_1st_fbref.csv
# data/ingest/fbref/advanced_match_stats/team/keeper/ITA_M_1st_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/team/keeper/USA_M_1st_fbref.csv
# data/ingest/fbref/advanced_match_stats/team/keeper/USA_M_1st_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/player/misc/USA_M_1st_fbref.csv
# data/ingest/fbref/advanced_match_stats/player/misc/USA_M_1st_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/player/passing_types/USA_M_1st_fbref.csv
# data/ingest/fbref/advanced_match_stats/player/passing_types/USA_M_1st_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/player/passing/USA_M_1st_fbref.csv
# data/ingest/fbref/advanced_match_stats/player/passing/USA_M_1st_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/player/defense/USA_M_1st_fbref.csv
# data/ingest/fbref/advanced_match_stats/player/defense/USA_M_1st_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/player/summary/ENG_M_3rd_fbref.csv
# data/ingest/fbref/advanced_match_stats/player/summary/ENG_M_3rd_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/player/summary/ENG_M_2nd_fbref.csv
# data/ingest/fbref/advanced_match_stats/player/summary/ENG_M_2nd_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/player/summary/ENG_M_4th_fbref.csv
# data/ingest/fbref/advanced_match_stats/player/summary/ENG_M_4th_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/player/summary/GER_M_1st_fbref.csv
# data/ingest/fbref/advanced_match_stats/player/summary/GER_M_1st_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/player/summary/ENG_M_5th_fbref.csv
# data/ingest/fbref/advanced_match_stats/player/summary/ENG_M_5th_fbref_0001.csv
# data/ingest/stage/advanced_match_stats/player/summary/ITA_M_1st_fbref.csv
# data/ingest/fbref/advanced_match_stats/player/summary/ITA_M_1st_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/player/summary/USA_M_1st_fbref.csv
# data/ingest/fbref/advanced_match_stats/player/summary/USA_M_1st_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/player/possession/USA_M_1st_fbref.csv
# data/ingest/fbref/advanced_match_stats/player/possession/USA_M_1st_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/player/keeper/GER_M_1st_fbref.csv
# data/ingest/fbref/advanced_match_stats/player/keeper/GER_M_1st_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/player/keeper/ITA_M_1st_fbref.csv
# data/ingest/fbref/advanced_match_stats/player/keeper/ITA_M_1st_fbref_0002.csv
# data/ingest/stage/advanced_match_stats/player/keeper/USA_M_1st_fbref.csv
# data/ingest/fbref/advanced_match_stats/player/keeper/USA_M_1st_fbref_0002.csv

# %%
 Path(next_path).with_name(f.name.replace("_fbref", "_fbref_*")).
# Out:
# PosixPath('data/ingest/fbref/advanced_match_stats/player/keeper/USA_M_1st_fbref_*.csv')

# %%
list(Path().glob('data/ingest/fbref/advanced_match_stats/player/keeper/USA_M_1st_fbref_*.csv'))
# Out:
# [PosixPath('data/ingest/fbref/advanced_match_stats/player/keeper/USA_M_1st_fbref_0001.csv')]

# %%
existing_files
# Out:
# [PosixPath('data/ingest/fbref/advanced_match_stats/player/keeper/USA_M_1st_fbref_0001.csv')]

# %%
import duckdb
import polars as pl
from pathlib import Path

EXTRACT_DIR = Path("data/extract")

db_conn = f"duckdb:///{str(EXTRACT_DIR / 'bayesball.db')}"
for f in  EXTRACT_DIR.glob("*.parquet"):
    print(f)
    pl.read_parquet(f).write_database(f.stem, db_conn, if_table_exists="replace")
# Out:
# data/extract/advanced_match_summary.parquet
# /Users/jimmy/Code/FantasyFootball/.venv/lib/python3.12/site-packages/duckdb_engine/__init__.py:184: DuckDBEngineWarning: duckdb-engine doesn't yet support reflection on indices
#   warnings.warn(
# data/extract/wages.parquet
# /Users/jimmy/Code/FantasyFootball/.venv/lib/python3.12/site-packages/duckdb_engine/__init__.py:184: DuckDBEngineWarning: duckdb-engine doesn't yet support reflection on indices
#   warnings.warn(
# data/extract/match_summary.parquet
# /Users/jimmy/Code/FantasyFootball/.venv/lib/python3.12/site-packages/duckdb_engine/__init__.py:184: DuckDBEngineWarning: duckdb-engine doesn't yet support reflection on indices
#   warnings.warn(
# data/extract/advanced_match_stats_player.parquet
# /Users/jimmy/Code/FantasyFootball/.venv/lib/python3.12/site-packages/duckdb_engine/__init__.py:184: DuckDBEngineWarning: duckdb-engine doesn't yet support reflection on indices
#   warnings.warn(
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 10
#       8 for f in  EXTRACT_DIR.glob("*.parquet"):
#       9     print(f)
# ---> 10     pl.read_parquet(f).write_database(f.stem, db_conn, if_table_exists="replace")
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/polars/dataframe/frame.py:4081, in DataFrame.write_database(self, table_name, connection, if_table_exists, engine, engine_options)
#    4077         raise ValueError(msg)
#    4079     # ensure conversion to pandas uses the pyarrow extension array option
#    4080     # so that we can make use of the sql/db export *without* copying data
# -> 4081     res: int | None = self.to_pandas(
#    4082         use_pyarrow_extension_array=True,
#    4083     ).to_sql(
#    4084         name=unpacked_table_name,
#    4085         schema=db_schema,
#    4086         con=sa_object,
#    4087         if_exists=if_table_exists,
#    4088         index=False,
#    4089         **(engine_options or {}),
#    4090     )
#    4091     return -1 if res is None else res
#    4093 elif isinstance(engine, str):
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/pandas/core/generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2889 """
#    2890 Write records stored in a DataFrame to a SQL database.
#    2891
#    (...)
#    3083 [(1,), (None,), (2,)]
#    3084 """  # noqa: E501
#    3085 from pandas.io import sql
# -> 3087 return sql.to_sql(
#    3088     self,
#    3089     name,
#    3090     con,
#    3091     schema=schema,
#    3092     if_exists=if_exists,
#    3093     index=index,
#    3094     index_label=index_label,
#    3095     chunksize=chunksize,
#    3096     dtype=dtype,
#    3097     method=method,
#    3098 )
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/pandas/io/sql.py:842, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     837     raise NotImplementedError(
#     838         "'frame' argument should be either a Series or a DataFrame"
#     839     )
#     841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#     845         if_exists=if_exists,
#     846         index=index,
#     847         index_label=index_label,
#     848         schema=schema,
#     849         chunksize=chunksize,
#     850         dtype=dtype,
#     851         method=method,
#     852         engine=engine,
#     853         **engine_kwargs,
#     854     )
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/pandas/io/sql.py:2018, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2006 sql_engine = get_engine(engine)
#    2008 table = self.prep_table(
#    2009     frame=frame,
#    2010     name=name,
#    (...)
#    2015     dtype=dtype,
#    2016 )
# -> 2018 total_inserted = sql_engine.insert_records(
#    2019     table=table,
#    2020     con=self.con,
#    2021     frame=frame,
#    2022     name=name,
#    2023     index=index,
#    2024     schema=schema,
#    2025     chunksize=chunksize,
#    2026     method=method,
#    2027     **engine_kwargs,
#    2028 )
#    2030 self.check_case_sensitive(name=name, schema=schema)
#    2031 return total_inserted
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/pandas/io/sql.py:1558, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1555 from sqlalchemy import exc
#    1557 try:
# -> 1558     return table.insert(chunksize=chunksize, method=method)
#    1559 except exc.StatementError as err:
#    1560     # GH34431
#    1561     # https://stackoverflow.com/a/67358288/6067848
#    1562     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1563     )|inf can not be used with MySQL"""
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/pandas/io/sql.py:1119, in SQLTable.insert(self, chunksize, method)
#    1116     break
#    1118 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1119 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1120 # GH 46891
#    1121 if num_inserted is not None:
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/pandas/io/sql.py:1010, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     998 """
#     999 Execute SQL statement inserting data
#    1000
#    (...)
#    1007    Each item contains a list of values to be inserted
#    1008 """
#    1009 data = [dict(zip(keys, row)) for row in data_iter]
# -> 1010 result = conn.execute(self.table.insert(), data)
#    1011 return result.rowcount
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/sqlalchemy/sql/elements.py:515, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     513     if TYPE_CHECKING:
#     514         assert isinstance(self, Executable)
# --> 515     return connection._execute_clauseelement(
#     516         self, distilled_params, execution_options
#     517     )
#     518 else:
#     519     raise exc.ObjectNotExecutableError(self)
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1630, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1622 schema_translate_map = execution_options.get(
#    1623     "schema_translate_map", None
#    1624 )
#    1626 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1627     "compiled_cache", self.engine._compiled_cache
#    1628 )
# -> 1630 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1631     dialect=dialect,
#    1632     compiled_cache=compiled_cache,
#    1633     column_keys=keys,
#    1634     for_executemany=for_executemany,
#    1635     schema_translate_map=schema_translate_map,
#    1636     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1637 )
#    1638 ret = self._execute_context(
#    1639     dialect,
#    1640     dialect.execution_ctx_cls._init_compiled,
#    (...)
#    1648     cache_hit=cache_hit,
#    1649 )
#    1650 if has_events:
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/sqlalchemy/sql/elements.py:716, in ClauseElement._compile_w_cache(self, dialect, compiled_cache, column_keys, for_executemany, schema_translate_map, **kw)
#     714 else:
#     715     extracted_params = None
# --> 716     compiled_sql = self._compiler(
#     717         dialect,
#     718         cache_key=elem_cache_key,
#     719         column_keys=column_keys,
#     720         for_executemany=for_executemany,
#     721         schema_translate_map=schema_translate_map,
#     722         **kw,
#     723     )
#     725     if not dialect._supports_statement_cache:
#     726         cache_hit = dialect.NO_DIALECT_SUPPORT
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/sqlalchemy/sql/elements.py:316, in CompilerElement._compiler(self, dialect, **kw)
#     314 if TYPE_CHECKING:
#     315     assert isinstance(self, ClauseElement)
# --> 316 return dialect.statement_compiler(dialect, self, **kw)
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/sqlalchemy/sql/compiler.py:1472, in SQLCompiler.__init__(self, dialect, statement, cache_key, column_keys, for_executemany, linting, _supporting_against, **kwargs)
#    1470 if self.positional:
#    1471     if self._numeric_binds:
# -> 1472         self._process_numeric()
#    1473     else:
#    1474         self._process_positional()
#
# File ~/Code/FantasyFootball/.venv/lib/python3.12/site-packages/sqlalchemy/sql/compiler.py:1735, in SQLCompiler._process_numeric(self)
#    1730     len_before = len(param_pos)
#    1731     param_pos = {
#    1732         self.escaped_bind_names.get(name, name): pos
#    1733         for name, pos in param_pos.items()
#    1734     }
# -> 1735     assert len(param_pos) == len_before
#    1737 # Can't use format here since % chars are not escaped.
#    1738 self.string = self._pyformat_pattern.sub(
#    1739     lambda m: param_pos[m.group(1)], self.string
#    1740 )
#
# AssertionError:
